# %% [markdown]
# <a href="https://colab.research.google.com/github/yasiruKodikara/DeepLearning-Specialization-stanford-online/blob/main/python_numpy_vectors_C1W2L17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.random.randn(5)

# %%
print(a)
# Out:
# [-0.59401775  0.51400176  0.75240613 -0.88071944 -0.06581327]

# %%
print(a.shape)
# Out:
# (5,)

# %%
print(a.T)
# Out:
# [-0.59401775  0.51400176  0.75240613 -0.88071944 -0.06581327]

# %%
a.reshape(5,1)
# Out:
# array([[-0.59401775],
#        [ 0.51400176],
#        [ 0.75240613],
#        [-0.88071944],
#        [-0.06581327]])

# %%
print(a.T)
# Out:
# [-0.59401775  0.51400176  0.75240613 -0.88071944 -0.06581327]
