# %% [markdown]
# <a href="https://colab.research.google.com/github/yasiruKodikara/DeepLearning-Specialization-stanford-online/blob/main/TensorFlow_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

# %%
w = tf.Variable(0, dtype=tf.float32 )
optimizer = tf.keras.optimizers.Adam(0.1)

def train_step():
  with tf.GradientTape() as tape:
    cost = w**2 - 10*w + 25
  trainable_variables = [w]
  grads = tape.gradient(cost, trainable_variables)
  optimizer.apply_gradients(zip(grads, trainable_variables))
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>

# %%
train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0999993085861206>

# %%
train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1999405324459076>

# %%
for i in range(1000):
  train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000000953674316>

# %%
w = tf.Variable(0, dtype=tf.float32 )
x = np.array([1.0, -10.0, 25.0], dtype=np.float32)
optimizer = tf.keras.optimizers.Adam(0.1)

def cost_fn():
  return x[0] * w**2 + x[1]*w + x[2]

print(w)

optimizer.minimize(cost_fn, [w])
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_17194/372144472.py in <cell line: 0>()
#       8 print(w)
#       9
# ---> 10 optimizer.minimize(cost_fn, [w])
#      11 print(w)
#
# AttributeError: 'Adam' object has no attribute 'minimize'
